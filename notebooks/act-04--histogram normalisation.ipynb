# %% [markdown]
# ## Histogram Normalisation for Enhancing Faint Patterns
#
# **Act 4**
#
# _Oct 25 - _
#
# ### Background

# %%
# %matplotlib inline

import skimage
import skimage.io
import skimage.morphology
import skimage.filters
import skimage.color
import skimage.segmentation
import skimage.util
import skimage.util.colormap

import matplotlib.pyplot as plt
import numpy as np
import os
import glob

import cv2

from collections import namedtuple

# %%
im = skimage.io.imread('imgs/oct-25/IMG_8116.JPG')
plt.imshow(im)

# %%
im_hsv = skimage.color.rgb2hsv(im)
plt.subplot(131)
plt.imshow(im_hsv[:,:,0], cmap=plt.cm.magma)
plt.subplot(132)
plt.imshow(im_hsv[:,:,1], cmap=plt.cm.magma)
plt.subplot(133)
plt.imshow(im_hsv[:,:,2], cmap=plt.cm.magma)

# %%
im_lab = skimage.color.rgb2lab(im)
plt.subplot(131)
plt.imshow(im_lab[:,:,0], cmap=plt.cm.magma)
plt.subplot(132)
plt.imshow(im_lab[:,:,1], cmap=plt.cm.magma)
plt.subplot(133)
plt.imshow(im_lab[:,:,2], cmap=plt.cm.magma)

# %%
im_luv = skimage.color.rgb2luv(im)
plt.subplot(131)
plt.imshow(im_luv[:,:,0], cmap=plt.cm.magma)
plt.subplot(132)
plt.imshow(im_luv[:,:,1], cmap=plt.cm.magma)
plt.subplot(133)
plt.imshow(im_luv[:,:,2], cmap=plt.cm.magma)

# %%
im_yuv = skimage.color.rgb2yuv(im)
plt.subplot(131)
plt.imshow(im_yuv[:,:,0], cmap=plt.cm.magma)
plt.subplot(132)
plt.imshow(im_yuv[:,:,1], cmap=plt.cm.magma)
plt.subplot(133)
plt.imshow(im_yuv[:,:,2], cmap=plt.cm.magma)

# %%
plt.set_cmap(plt.cm.viridis)

im2 = skimage.io.imread('imgs/oct-25/IMG_2134_crop.JPG', as_grey=True)
plt.imshow(im2)

# %%
plt.imshow(skimage.morphology.thin(im2))

# %%
disk = skimage.morphology.disk(50)
plt.imshow(skimage.morphology.closing(im2, disk))

# %%
plt.imshow(skimage.exposure.equalize_adapthist(im2, kernel_size=100))
# Out:
# /Users/prashantsinha/.pyenv/versions/3.5.2/lib/python3.5/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint16
#   .format(dtypeobj_in, dtypeobj_out))

# %%
plt.imshow(skimage.morphology.thin(im2, max_iter=50))
